MMMMMMMMMMMMMMMMMMMMMMM
# MMMMMMMMMMMMMMMMMMMMMMMMMMNkdd0WMMWXkddOXWMMMMMMMMMMMMMMMMMWN0xdx0NMMWXxoxKWMMMMMMMMMMMMMMMMMMMMMMMM
# MMMMMMMMMMMMMMMMMMMMMMMMMMMXkdx0NMMWN0xdxOKNWMMMMMMMMMMMMWX0xddOXWMMWKxdxKWMMMMMMMMMMMMMMMMMMMMMMMMM
# MMMMMMMMMMMMMMMMMMMMMMMMMMMMNOxdOXWMMWN0kxdxO0KKXNNNXXK0OkddxOXWMMMN0xdkKWMMMMMMMMMMMMMMMMMMMMMMMMMM
# MMMMMMMMMMMMMMMMMMMMMMMMMMMMMWKkxx0NWMMMWXKOkxxxxxxxxxxxkO0XNWMMWNKkdx0NWMMMMMMMMMMMMMMMMMMMMMMMMMMM
# MMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMN0kxk0XWMMMMMWNXXKKKKKKXNNWWMMMWX0kxxOXWMMMMMMMMMMMMMMMMMMMMMMMMMMMMM
# MMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMWNKOxxk0KNWWMMMMMMMMMMMMMMWNX0Oxxk0XWMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMM
# MMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMWNNNK0kxxkOO0KKXXXNXXXXK00OkxxxO0XNNNWWMMMMMMMMMMMMMMMMMMMMMMMMMMMMM
# MMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMN0kkOOkkxxxxxxxxxxkkkxxxxxxxxxxxkkkkkkOKWMMMMMMMMMMMMMMMMMMMMMMMMMMMM
# MMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMWXKKKKKKKKKKKKKKKKKKKKKKKKKKKKKKKKKKKKKXWMMMMMMMMMMMMMMMMMMMMMMMMMMMM
# MMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMM
# ```

# %%
#Every possible symbol that can be encrypted/decrypted
#Using key = 13, we get the ROT13 or the rotate by 13 cipher, with is a substituion cipher, where the key is can be used for both encrypt and decrypt (13x2)
SYMBOLS = 'ABCDEFGHIJKLMNOPQRSTUVWXYZ'

# %% [markdown]
# ### Caesar Cipher Visualized
# Reference: https://en.wikipedia.org/wiki/Caesar_cipher
# #### Pic 1: You shift using a physical lever, and hide the key
# #### Pic 2: How the shifting looks like
#
# ![440px-CipherDisk2000.jpeg](data:image/jpeg;base64,...)
# ![440px-Caesar_cipher_left_shift_of_3.svg.png](data:image/png;base64,...)

# %%
while True: #Keep asking until the user enters e or d
  print('Do you want to (e)ncrypt, or (d)ecrypt')
  response = input('> '). lower()
  if response.startswith('e'):
    mode = 'encrypt'
    break
  elif response.startswith('d'):
    mode = 'decrypt'
    break
  print('Please enter the letter e or d.')

while True: #Keep asking until the user enters a valid key
  maxKey = len(SYMBOLS) - 1
  print('Please enter the key (0 to {}) to use'.format(maxKey))
  response = input('> ').upper()
  if not response.isdecimal():
    continue
  
  if 0 <= int(response) < len(SYMBOLS):
    key = int(response)
    break

#Stores the encrypted/decrypted form of the message:
translated = ''

#Let the user enter the message to encrypt/decrypt:
print('Enter the message to {}'.format(mode))
message = input('> ')

#Caesar cipher only works on upper case letters:
message = message.upper()



#Encrypt/decrypt
for symbol in message:
  if symbol in SYMBOLS:
    #Get the encrypted (or decrypted) number for this symbol.
    num = SYMBOLS.find(symbol) #Get the number of the symbol.
    #This is where you are going backwards or forward. 
    if mode == 'encrypt':
      num = num+key
    elif mode == 'decrypt':
      num = num - key
    #Handle the wrap-around if num is larger than the length of the symbols or less than 0 
    #Symbols or less than 0

    num = num % len(SYMBOLS)
    # if num >= len(SYMBOLS):
    #   num = num - len(SYMBOLS)
    # elif num < 0:
    #   num = num + len(SYMBOLS)
    
    #Add encrypted/decrypted number's symbol to translated:
    translated = translated + SYMBOLS[num]
  else:
    # Just add the symbol without encrypting/decrypting:
    translated = translated + symbol

# Display the encrypted/decrypted string to the screen:
print(translated)
# Out:
# Do you want to (e)ncrypt, or (d)ecrypt
# > e
# Please enter the key (0 to 25) to use
# > 10
# Enter the message to encrypt
# > a
# K

# %%
from google.colab import drive
drive.mount('/content/gdrive', force_remount=True)
print('Google Drive connected.')

# %% [markdown]
# ### Download the *dictionary.txt* file from Google Drive here: [Click here](https://drive.google.com/file/d/1z-eGIkrtRg71P2XQF0nJf1e2sre1RL8K/view?usp=sharing)

# %%
DATA_PATH = "/content/drive/MyDrive/YOUR_FOLDER_NAME/dictionary.txt"

def loadDictionary():
  dictionaryFile = open(DATA_PATH)
  englishWords = {}
  for word in dictionaryFile.read().split('\n'):
    englishWords[word] = None
  dictionaryFile.close()
  return englishWords

ENGLISH_WORDS = loadDictionary()

def getEnglishCount(message):
  message = message.upper()
  possibleWords = message.split()

  if possibleWords == []:
    return 0.0 #No words at all, so return 0.0

  matches = 0
  for word in possibleWords:
    if word in ENGLISH_WORDS:
      matches +=1
  return float(matches)/len(possibleWords)

def isEnglish(message, wordPercentage=20):
  #By default, 20$ of thr words must exist in the dictionary files
  #85% of all characters must be letters or spaces, nothing weird like punctuations
  wordsMatch = getEnglishCount(message) * 100 >= wordPercentage
  return wordsMatch

# %%
# Let the user specify the message to hack:
print('Enter the encrypted Caesar cipher message to hack.')
message = input('> ')


for key in range(len(SYMBOLS)): #LOOP THROUGH EVERY KEY
  translated = ''
  
  #Decrypt each symbol in the message
  for symbol in message:
    if symbol in SYMBOLS:
      num = SYMBOLS.find(symbol) #Get the number of the symbol
      num = num - key #Decrypt the number

      #Handle the wrap-around if num is less than 0:
      if num < 0:
        num = num + len(SYMBOLS)

      #Add decrypted number's symbol to translate:
      translated = translated + SYMBOLS[num]
    else:
      #Just add symbol
      translated = translated+symbol


  #Display the key being tested along with its decrypted text:
  print('Key #{}: {}; English: {}'.format(key, translated, isEnglish(translated)))
# Out:
# Enter the encrypted Caesar cipher message to hack.
# > hello
# Key #0: hello; English: True
# Key #1: hello; English: True
# Key #2: hello; English: True
# Key #3: hello; English: True
# Key #4: hello; English: True
# Key #5: hello; English: True
# Key #6: hello; English: True
# Key #7: hello; English: True
# Key #8: hello; English: True
# Key #9: hello; English: True
# Key #10: hello; English: True
# Key #11: hello; English: True
# Key #12: hello; English: True
# Key #13: hello; English: True
# Key #14: hello; English: True
# Key #15: hello; English: True
# Key #16: hello; English: True
# Key #17: hello; English: True
# Key #18: hello; English: True
# Key #19: hello; English: True
# Key #20: hello; English: True
# Key #21: hello; English: True
# Key #22: hello; English: True
# Key #23: hello; English: True
# Key #24: hello; English: True
# Key #25: hello; English: True
